# %%
import pandas as pd

# %%
df = pd.read_csv('AB_NYC_2019.csv')
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df['ppn'] = df['price']/df['minimum_nights']
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df['ppn'].describe()
# Out:
# count    48895.000000
# mean        70.174247
# std        157.620388
# min          0.000000
# 25%         20.000000
# 50%         44.500000
# 75%         81.500000
# max       8000.000000
# Name: ppn, dtype: float64

# %%
import seaborn as sns
ax = sns.boxplot(df['ppn'])

# %%
max_out = df['ppn'].quantile(0.9999)
max_out
# Out:
# 6533.17999999781

# %%
df[df['ppn']>max_out]
# Out:
#              id                                       name    host_id  \
# 4377    2953058                              Film Location    1177497
# 29662  22779726  East 72nd Townhouse by (Hidden by Airbnb)  156158778
# 42523  33007610        70' Luxury MotorYacht on the Hudson    7407743
# 44034  33998396           3000 sq ft daylight photo studio    3750764
# 45666  34895693                       Gem of east Flatbush  262534951
#
#       host_name neighbourhood_group      neighbourhood  latitude  longitude  \
# 4377    Jessica            Brooklyn       Clinton Hill  40.69137  -73.96723
# 29662     Sally           Manhattan    Upper East Side  40.76824  -73.95989
# 42523      Jack           Manhattan  Battery Park City  40.71162  -74.01693
# 44034     Kevin           Manhattan            Chelsea  40.75060  -74.00388
# 45666    Sandra            Brooklyn      East Flatbush  40.65724  -73.92450
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
min_out = df['ppn'].quantile(0.01)
min_out
# Out:
# 1.2333333333333334

# %%
df[df['ppn']<min_out].count()
# Out:
# id                                485
# name                              484
# host_id                           485
# host_name                         485
# neighbourhood_group               485
# neighbourhood                     485
# latitude                          485
# longitude                         485
# room_type                         485
# price                             485
# minimum_nights                    485
# number_of_reviews                 485
# last_review                       264
# reviews_per_month                 264
# calculated_host_listings_count    485
# availability_365                  485
# ppn                               485
# dtype: int64

# %%
df1 = df[(df['ppn']>min_out)&(df['ppn']<max_out)]

# %%
df1.shape
# Out:
# (48383, 17)

# %%
df1['ppn'].describe()
# Out:
# count    48383.000000
# mean        70.132959
# std        139.049656
# min          1.240000
# 25%         20.000000
# 50%         45.000000
# 75%         82.500000
# max       6500.000000
# Name: ppn, dtype: float64
